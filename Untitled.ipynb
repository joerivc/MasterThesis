# %%
# !pip install fastai
# Out:
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.4
#     Uninstalling colorama-0.4.4:
#       Successfully uninstalled colorama-0.4.4
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# ...

# %%
#importing libraries
from fastai import *
#from fastai.vision import *
from fastai.vision.data import ImageDataLoaders
from fastai.vision.all import *
from fastai.metrics import error_rate
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from pathlib import Path

# %%
x  = 'C:\\Users\\Joeri Van Cauwelaert\\Desktop\\Masterthesis\\machineLearning\\Images'
path = Path(x)
path.ls()
# Out:
# (#4) [Path('C:/Users/Joeri Van Cauwelaert/Desktop/Masterthesis/machineLearning/Images/Sitting'),Path('C:/Users/Joeri Van Cauwelaert/Desktop/Masterthesis/machineLearning/Images/SittingPelvicR'),Path('C:/Users/Joeri Van Cauwelaert/Desktop/Masterthesis/machineLearning/Images/Standing'),Path('C:/Users/Joeri Van Cauwelaert/Desktop/Masterthesis/machineLearning/Images/StandingPelvicR')]

# %%
data = ImageDataLoaders.from_folder(path, train='.', valid_pct=0.2, 
                                    item_tfms=Resize(460), 
                                    batch_tfms=[*aug_transforms(size=224), Normalize.from_stats(*imagenet_stats)],
                                    num_workers=4)

# %%
np.random.seed(40)
# Determine the aspect ratio of your images (720x480)
aspect_ratio = 720 / 480

# Choose a target width or height that maintains the aspect ratio
target_width = 224
target_height = int(target_width / aspect_ratio)  # Calculate height based on aspect ratio
data = ImageDataLoaders.from_folder(path, train = '.', valid_pct=0.2,
                                  ds_tfms=aug_transforms(), size=(target_height, target_width),
                                  num_workers=4)#.normalize(imagenet_stats)

# %%
data.show_batch(figsize=(7,6))

# %%
data

# %%
print(data.classes)
len(data.classes)
data.c
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\JOERIV~1\AppData\Local\Temp/ipykernel_13848/3977363045.py in <module>
# ----> 1 print(data.classes)
#       2 len(data.classes)
#       3 data.c
#
# ~\anaconda3\lib\site-packages\fastcore\basics.py in __getattr__(self, k)
#     494         if self._component_attr_filter(k):
#     495             attr = getattr(self,self._default,None)
# --> 496             if attr is not None: return getattr(attr,k)
#     497         raise AttributeError(k)
#     498     def __dir__(self): return custom_dir(self,self._dir())
#
# ~\anaconda3\lib\site-packages\fastcore\basics.py in __getattr__(self, k)
#     494         if self._component_attr_filter(k):
#     495             attr = getattr(self,self._default,None)
# --> 496             if attr is not None: return getattr(attr,k)
#     497         raise AttributeError(k)
# ...

# %%
learn = cnn_learner(data, models.resnet18, metrics=[accuracy], model_dir = Path('../kaggle/working'),path = Path("."))
# Out:
# C:\Users\Joeri Van Cauwelaert\anaconda3\lib\site-packages\fastai\vision\learner.py:301: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\Joeri Van Cauwelaert/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 44.7M/44.7M [00:08<00:00, 5.65MB/s]

# %%
learn.lr_find()
#learn.recorder.plot(suggestions=True)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/4 00:00&lt;?]
#     </div>
#
#
#
#     <div>
#       <progress value='2' class='' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.67% [2/30 01:58&lt;27:42 0.2620]
#     </div>

# %%
learn.recorder.plot(suggestions=True)

# %%
lr1 = 1e-3
lr2 = 1e-1
learn.fit_one_cycle(40,slice(lr1,lr2))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.50% [1/40 27:23&lt;17:48:32]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
# ...
